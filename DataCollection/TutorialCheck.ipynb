# %%
import json
import os

'''
    only runs check on last folder
'''
# Out:
# '\n    only runs check on last folder\n'

# %%
path = "TutorialData"
dir_list = os.listdir(path)
 
print("Files and directories in '", path, "' :")
 
# prints all files
print(dir_list)

tutorial_paths = []

for filename in dir_list:
    tutorial_paths.append(path + "//" + filename + "//Tutorial//")

print(tutorial_paths)

tutorial_paths = [tutorial_paths[len(tutorial_paths) - 1]] #only checks most recent
# Out:
# Files and directories in ' TutorialData ' :
# ['1652652612716', '1652662508478']
# ['TutorialData//1652652612716//Tutorial//', 'TutorialData//1652662508478//Tutorial//']

# %%
def parseFileNumber(fileName):
    fragments = fileName.split('_')
    return float(fragments[1])

# %%
import pandas as pd 
import numpy as np
import itertools
pd.options.display.max_rows = None

# %%
responsiveData = []
experimentEvents = []

def parseFrame(frames):
    frames_list = []
    for frame in frames:
        frameData = {
            "frameNum": int,
            "unixTime": float,
            "timestamp": float,
            "hPos": {"x":float,"y":float,"z":float},
            "hDir": {"x":float,"y":float,"z":float},
            "hRot": {"i":float,"j":float,"k":float},
            "hAngl": {"x":float,"y":float,"z":float},
            "gazeOrigin": {"x":float,"y":float,"z":float},
            "gazeDirection": {"x":float,"y":float,"z":float},
            "rightHandRay": {"x":float,"y":float,"z":float},
            "leftHandRay": {"x":float,"y":float,"z":float},
            "experimentEvents": [],
            "responsiveData": []
        }
        responsiveEvent = frame["responsiveData"]
        experimentEvent = frame["experimentEvents"]
        frameData["frameNum"] = frame["frameNum"]
        frameData["unixTime"] = frame["unixTime"]
        frameData["timestamp"] = frame["timestamp"]
        frameData["hPos"] = frame["hPos"]
        frameData["hDir"] = frame["hDir"]
        frameData["hRot"] = frame["hRot"]
        frameData["hAngl"] = frame["hAngl"]
        frameData["gazeOrigin"] = frame["gazeOrigin"]
        frameData["gazeDirection"] = frame["gazeDirection"]
        frameData["rightHandRay"] = frame["rightHandRay"]
        frameData["leftHandRay"] = frame["leftHandRay"]
        frameData["experimentEvents"] = experimentEvent
        frameData["responsiveData"] = responsiveEvent
        frames_list.append(frameData)
        if responsiveEvent:
            responsiveData.append(responsiveEvent)
        if experimentEvent:
            experimentEvents.append(experimentEvent)
    return frames_list

def parseSession(session):
    sessionData = {
    "numFrames": int,
    "task": str,
    "start_time": float,
    "end_time": float,
    "total_time": float,
    "sessionNumber": int,
    "isResponsive": int
    }
    sessionData["numFrames"] = session["numFrames"]
    sessionData["task"] = session["task"]
    sessionData["start_time"] = session["start_time"]
    sessionData["end_time"] = session["end_time"]
    sessionData["total_time"] = session["total_time"]
    sessionData["sessionNumber"] = session["sessionNumber"]
    sessionData["isResponsive"] = session["isResponsive"]
    return sessionData

# %%
data = []
frames = []
allsession = []

for exp in tutorial_paths:
    experiment_data = {
    "path" : str,
    "sessions": {}
    }
    sessions = {}
    experiment = os.listdir(exp)
    current_path = exp
    experiment_data["path"] = current_path
    experiment.sort(key=parseFileNumber)
    for filename in experiment:
        if filename.endswith(".json"):
            # Prints only text file present in My Folder
            print(filename)
            firstFileFlag = False
            if("Session_0" in filename):
                firstFileFlag = True
            with open(current_path + filename, 'r') as f:
                json_data = json.load(f)
                if(firstFileFlag):
                    session = parseSession(json_data["obj"]["sessionRecordings"][0])
                    num = session["sessionNumber"]
                    sessions[num] = session
                    frame = parseFrame(json_data["obj"]["sessionRecordings"][0]["frames"])
                    frames.append(frame)
                    allsession.append(session)
                else:
                    session = parseSession(json_data)
                    num = session["sessionNumber"]
                    sessions[num] = session
                    frame = parseFrame(json_data["frames"])
                    frames.append(frame)
                    allsession.append(session)
    experiment_data["sessions"] = sessions
    data.append(experiment_data)

print(data)
# Out:
# TutorialSession_0_1652662508478.json
# TutorialSession_1_1652662508478.json
# TutorialSession_2_1652662508478.json
# TutorialSession_3_1652662508478.json
# TutorialSession_4_1652662508478.json
# TutorialSession_5_1652662508478.json
# TutorialSession_6_1652662508478.json
# TutorialSession_7_1652662508478.json
# TutorialSession_8_1652662508478.json
# [{'path': 'TutorialData//1652662508478//Tutorial//', 'sessions': {0: {'numFrames': 36, 'task': "Select a hologram or button within arm's reach by tapping it with your finger. This is how you interact with holograms nearby. \n\nPractice near select by selecting a button.", 'start_time': 1652662510948, 'end_time': 1652662512328, 'total_time': 1380, 'sessionNumber': 0, 'isResponsive': False}, 1: {'numFrames': 17, 'task': 'Select a hologram that\'s out of reach by targeting it with the ray from the palm of your hand. Then tap and release your index finger and thumb to select it. This is called "Air tap."\n\nPractice air tap by selecting a button', 'start_time': 1652662512398, 'end_time': 1652662514168, 'total_time': 1770, 'sessionNumber': 1, 'isResponsive': False}, 2: {'numFrames': 12, 'task': 'You have learned two different ways to select holograms using near select and air tap. Next, you will be asked to select specific items. \n\nSelect "Continue"', 'start_time': 1652662514177, 'end_time': 1652662515318, 'total_time': 1141, 'sessionNumber': 2, 'isResponsive': False}, 3: {'numFrames': 12, 'task': 'Select "Button Two" under Buttons', 'start_time': 1652662515318, 'end_time': 1652662516728, 'total_time': 1410, 'sessionNumber': 3, 'isResponsive': False}, 4: {'numFrames': 10, 'task': 'Select the text that says "Select me" under Selectable Text', 'start_time': 1652662516737, 'end_time': 1652662517658, 'total_time': 921, 'sessionNumber': 4, 'isResponsive': False}, 5: {'numFrames': 9, 'task': 'Select and hold the the circle under Slider and move it to the right.', 'start_time': 1652662517668, 'end_time': 1652662518618, 'total_time': 950, 'sessionNumber': 5, 'isResponsive': False}, 6: {'numFrames': 44, 'task': 'Select the input box under the Input Field. After selecting the input box, a keyboard will appear. Type on the keyboard then select enter.', 'start_time': 1652662518627, 'end_time': 1652662523068, 'total_time': 4441, 'sessionNumber': 6, 'isResponsive': False}, 7: {'numFrames': 19, 'task': 'Scroll down by selecting and holding the blue background then move your hand in an upwards motion. \nAfter you scroll down, click the text that says "You found me".', 'start_time': 1652662523078, 'end_time': 1652662524947, 'total_time': 1869, 'sessionNumber': 7, 'isResponsive': False}, 8: {'numFrames': 1, 'task': '', 'start_time': 0, 'end_time': 0, 'total_time': 0, 'sessionNumber': 8, 'isResponsive': False}}}]

# %%
responsive_data = []
nonresponsive_data = []

for d in data:
    #change to Responsive 
    if(d["sessions"][0]["isResponsive"]):
        responsive_data.append(d)
    else:
        nonresponsive_data.append(d)

#print(responsive_data)
#print(nonresponsive_data)

# %%
frames
framesUnpacked = list(itertools.chain(*frames))
framesDf = pd.DataFrame(framesUnpacked)

framesDf = framesDf.sort_values(by='timestamp')
framesDf.head(1)
# Out:
#    frameNum       unixTime  timestamp  \
# 0         1  1652662508707        229
#
#                                                 hPos  \
# 0  {'x': -0.040359847247600555, 'y': -0.009926516...
#
#                                                 hDir  \
# 0  {'x': 0.03832792490720749, 'y': 0.010831710882...
#
#                                                 hRot  \
# 0  {'x': -0.0059559959918260574, 'y': 0.019007168...
#
#                                                hAngl  \
# 0  {'x': 359.3793640136719, 'y': 2.19669508934021...
#
#                                           gazeOrigin  \
# 0  {'x': -0.03567313775420189, 'y': -0.0087075727...
#
#                                        gazeDirection  \
# 0  {'x': 0.03282273933291435, 'y': 0.010392103344...
#
#                      rightHandRay                     leftHandRay  \
# 0  {'x': 0.0, 'y': 0.0, 'z': 0.0}  {'x': 0.0, 'y': 0.0, 'z': 0.0}
#
#   experimentEvents                                     responsiveData
# 0               []  {'scale': {'x': 0.0, 'y': 0.0, 'z': 0.0}, 'pos...

# %%
leftRay = framesDf.loc[framesDf["leftHandRay"] != {'x': 0.0, 'y': 0.0, 'z': 0.0}]
rightRay = framesDf.loc[framesDf["rightHandRay"] != {'x': 0.0, 'y': 0.0, 'z': 0.0}]
leftRay["leftHandRay"].count()
assert(leftRay["leftHandRay"].count() + rightRay["rightHandRay"].count() > 0)
leftRay["leftHandRay"].count() + rightRay["rightHandRay"].count()
# Out:
# 150

# %%
experimentEvents

experimentEventsUnpacked = list(itertools.chain(*experimentEvents))
experimentEventsDf = pd.DataFrame(experimentEventsUnpacked)
experimentEventsDf = experimentEventsDf.sort_values(by='unixTime')
experimentEventsDf
# Out:
#          unixTime   systemTime  isResponsive eventName  task_number  \
# 0   1652662510878  17-55-10-87         False     start            1
# 1   1652662512328  17-55-12-32         False   entered            1
# 2   1652662512328  17-55-12-32         False       end            1
# 3   1652662512328  17-55-12-32         False     start            2
# 4   1652662514168  17-55-14-16         False   entered            2
# 5   1652662514168  17-55-14-16         False       end            2
# 6   1652662514177  17-55-14-17         False     start            3
# 7   1652662515318  17-55-15-31         False   entered            3
# 8   1652662515318  17-55-15-31         False       end            3
# 9   1652662515318  17-55-15-31         False     start            4
# 10  1652662516728  17-55-16-72         False   entered            4
# 11  1652662516728  17-55-16-72         False       end            4
# 12  1652662516737  17-55-16-73         False     start            5
# 13  1652662517658  17-55-17-65         False   entered            5
# 14  1652662517658  17-55-17-65         False       end            5
# 15  1652662517668  17-55-17-66         False     start            6
# 16  1652662518618  17-55-18-61         False   entered            6
# 17  1652662518618  17-55-18-61         False       end            6
# 18  1652662518627  17-55-18-62         False     start            7
# 19  1652662518658  17-55-18-65         False   entered            7
# 20  1652662518703  17-55-18-70         False   entered            7
# 21  1652662518747  17-55-18-74         False   entered            7
# 22  1652662518808  17-55-18-80         False   entered            7
# 23  1652662518848  17-55-18-84         False   entered            7
# 24  1652662518907  17-55-18-90         False   entered            7
# 25  1652662519018  17-55-19-01         False   entered            7
# 26  1652662523068  17-55-23-06         False   entered            7
# 27  1652662523068  17-55-23-06         False       end            7
# 28  1652662523078  17-55-23-07         False     start            8
# 29  1652662524947  17-55-24-94         False   entered            8
# 30  1652662524947  17-55-24-94         False       end            8
#
#               task_type                                       object_scale  \
# 0   Near Select Example                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 1   Near Select Example                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 2   Near Select Example                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 3    Far Select Example                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 4    Far Select Example                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 5    Far Select Example                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 6            Task Popup                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 7            Task Popup  {'x': 1.5081454515457153, 'y': 1.5081454515457...
# 8            Task Popup  {'x': 1.5081454515457153, 'y': 1.5081454515457...
# 9         Select Button                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 10        Select Button                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 11        Select Button                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 12          Select Text                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 13          Select Text                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 14          Select Text                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 15        Select Slider                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 16        Select Slider                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 17        Select Slider                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 18         Select Input                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 19         Select Input                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 20         Select Input                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 21         Select Input                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 22         Select Input                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 23         Select Input                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 24         Select Input                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 25         Select Input                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 26         Select Input                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 27         Select Input                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 28               Scroll                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 29               Scroll                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# 30               Scroll                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
#
#                                       object_position correct_answer guess
# 0   {'x': 0.5910000205039978, 'y': -0.166000008583...              1
# 1   {'x': 0.5910000205039978, 'y': -0.166000008583...              1     1
# 2   {'x': 0.5910000205039978, 'y': -0.166000008583...              1     1
# 3   {'x': 0.2296999990940094, 'y': -0.090000003576...              2
# 4   {'x': 0.2296999990940094, 'y': -0.090000003576...              2     2
# 5   {'x': 0.2296999990940094, 'y': -0.090000003576...              2     2
# 6                      {'x': 0.0, 'y': 0.0, 'z': 0.5}              3
# 7   {'x': 0.03851209580898285, 'y': 0.046222977340...              3     3
# 8   {'x': 0.03851209580898285, 'y': 0.046222977340...              3     3
# 9                     {'x': 0.0, 'y': 0.0, 'z': 0.75}              4
# 10                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              4     4
# 11                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              4     4
# 12                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              5
# 13                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              5     5
# 14                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              5     5
# 15                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              6
# 16                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              6     6
# 17                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              6     6
# 18                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              7
# 19                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              7     6
# 20                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              7     6
# 21                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              7     6
# 22                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              7     6
# 23                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              7     6
# 24                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              7     6
# 25                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              7     6
# 26                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              7     7
# 27                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              7     7
# 28                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              8
# 29                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              8     8
# 30                    {'x': 0.0, 'y': 0.0, 'z': 0.75}              8     8

# %%
#Count number of start events
experimentEventsDf
startEvents = experimentEventsDf[experimentEventsDf['eventName'] == 'start']
#startEvents
assert(startEvents["unixTime"].count() == 8)

# %%
#Count number of complete events
completeEvents = experimentEventsDf[experimentEventsDf['eventName'] == 'end']
assert(completeEvents["unixTime"].count() == 8)

# %%
#Count number of answer events
answerEvents = experimentEventsDf[experimentEventsDf['eventName'] == 'entered']
assert(answerEvents["unixTime"].count() >= 8)

# %%
allsession

sessionsUnpacked = list(itertools.chain(allsession))
sessionsDf = pd.DataFrame(sessionsUnpacked)
sessionsDf = sessionsDf.sort_values(by='sessionNumber')

sessionsDf = sessionsDf.loc[sessionsDf["sessionNumber"] < 8 ]
sessionsDf
# Out:
#    numFrames                                               task  \
# 0         36  Select a hologram or button within arm's reach...
# 1         17  Select a hologram that's out of reach by targe...
# 2         12  You have learned two different ways to select ...
# 3         12                  Select "Button Two" under Buttons
# 4         10  Select the text that says "Select me" under Se...
# 5          9  Select and hold the the circle under Slider an...
# 6         44  Select the input box under the Input Field. Af...
# 7         19  Scroll down by selecting and holding the blue ...
#
#       start_time       end_time  total_time  sessionNumber  isResponsive
# 0  1652662510948  1652662512328        1380              0         False
# 1  1652662512398  1652662514168        1770              1         False
# 2  1652662514177  1652662515318        1141              2         False
# 3  1652662515318  1652662516728        1410              3         False
# 4  1652662516737  1652662517658         921              4         False
# 5  1652662517668  1652662518618         950              5         False
# 6  1652662518627  1652662523068        4441              6         False
# 7  1652662523078  1652662524947        1869              7         False

# %%
avg = 0
count = 0
for time in sessionsDf["total_time"]:
    assert(time > 0)
    avg = time + avg
    count = count + 1

print("avg: " + str(avg/count) + " milliseconds")
# Out:
# avg: 1735.25 milliseconds
